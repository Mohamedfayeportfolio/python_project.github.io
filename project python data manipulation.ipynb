# %%
import pandas as pd

# %%
df5=pd.read_csv('data (1).csv')

# %% [markdown]
# df5

# %%
df.head()
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df.tail()
# Out:
#        id        date first_name last_name                       email  \
# 995   996  03/24/2021       Duff    Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame   Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty  Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito     Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle  Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country price_paid   tax
# 995  Female  193.84.247.144         France      $3.63   NaN
# 996  Female  188.219.12.109            NaN      $4.59  20.0
# 997    Male    199.80.60.87  United States      $7.54  20.0
# 998    Male     0.183.63.11  United States      $5.81   NaN
# 999     NaN  170.193.249.83         Canada      $8.01  20.0

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# modifier lindex

# %%
df.set_index('email')
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df.set_index('email', inplace = True)

# %%
df
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df.index
# Out:
# Index(['malders0@shop-pro.jp', 'hharridge1@gnu.org', 'ekilminster2@etsy.com',
#        'gbrantl3@umn.edu', 'kbeasant4@jigsy.com', 'tbraybrooke5@umn.edu',
#        'akencott6@phoca.cz', 'cfeasley7@ed.gov', 'wheersema8@tumblr.com',
#        'ggookes9@amazon.co.uk',
#        ...
#        'sthorburnri@prnewswire.com', 'ecrushrj@berkeley.edu',
#        'mguilloneaurk@about.me', 'osnellerl@nhs.uk',
#        'cbruntjenrm@reference.com', 'derrigorn@elpais.com',
#        'arastallro@toplist.cz', 'bstickelsrp@cloudflare.com',
#        'ptesoerq@rakuten.co.jp', 'rpringuerrr@house.gov'],
#       dtype='object', name='email', length=1000)

# %%
# selectionner des donneés

# %%
df2
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df2.head ()
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df2['email'].head()
# Out:
# 0     malders0@shop-pro.jp
# 1       hharridge1@gnu.org
# 2    ekilminster2@etsy.com
# 3         gbrantl3@umn.edu
# 4      kbeasant4@jigsy.com
# Name: email, dtype: object

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df2.email)
# Out:
# pandas.core.series.Series

# %%
df2[10:20]
# Out:
#     id        date first_name  last_name                       email  gender  \
# 10  11  03/11/2021       Lief  Woodcraft   lwoodcrafta@sitemeter.com    Male
# 11  12  03/16/2021     Bailie      Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice   Morillas  jmorillasc@miibeian.gov.cn  Female
# 13  14  03/24/2021       Cull     Vassie          cvassied@unblog.fr     NaN
# 14  15  03/21/2021     Oralie     Maryon             omaryone@va.gov  Female
# 15  16  03/24/2021     Julina      Faint        jfaintf@amazon.co.jp  Female
# 16  17  03/27/2021        Eve    Allaway        eallawayg@ebay.co.uk  Female
# 17  18  03/20/2021       Esta    Boulden     ebouldenh@posterous.com     NaN
# 18  19  03/16/2021      Judye      Behan           jbehani@google.es  Female
# 19  20  03/01/2021     Sibeal     Mounch      smounchj@rakuten.co.jp    Male
#
#          ip_address        country price_paid   tax
# 10    201.76.240.51         Canada      $5.71   NaN
# ...

# %%
df2.loc[20:25]
# Out:
#     id        date first_name last_name                    email  gender  \
# 20  21  03/12/2021    Jeffrey   Stanman    jstanmank@latimes.com  Female
# 21  22  03/05/2021     Mendie      Ayer   mayerl@squarespace.com    Male
# 22  23  03/03/2021     Muriel    Pexton        mpextonm@bing.com    Male
# 23  24  03/09/2021    Ermanno     Ghost      eghostn@webnode.com    Male
# 24  25  03/02/2021        Tod   Willets  twilletso@artisteer.com    Male
# 25  26  03/14/2021       Nobe  Stobbart       nstobbartp@php.net  Female
#
#          ip_address        country price_paid   tax
# 20     3.110.64.192         France      $5.55  20.0
# 21    166.97.124.52         Canada      $4.86  20.0
# 22   113.10.187.192         Canada      $6.72  20.0
# 23  144.170.210.226         Canada      $9.79   NaN
# 24    101.42.146.88         Canada      $8.23   NaN
# 25  126.155.177.249  United States      $9.90   NaN

# %%
df2_email = df2.set_index('email')
df2_email.loc['mpextonm@bing.com']
# Out:
# id                        23
# date              03/03/2021
# first_name            Muriel
# last_name             Pexton
# gender                  Male
# ip_address    113.10.187.192
# country               Canada
# price_paid             $6.72
# tax                     20.0
# Name: mpextonm@bing.com, dtype: object

# %%
df2_email.loc[['smounchj@rakuten.co.jp','jstanmank@latimes.com','omaryone@va.gov']]
# Out:
#                         id        date first_name last_name  gender  \
# email
# smounchj@rakuten.co.jp  20  03/01/2021     Sibeal    Mounch    Male
# jstanmank@latimes.com   21  03/12/2021    Jeffrey   Stanman  Female
# omaryone@va.gov         15  03/21/2021     Oralie    Maryon  Female
#
#                             ip_address        country price_paid   tax
# email
# smounchj@rakuten.co.jp    218.17.7.177         Canada      $5.82  20.0
# jstanmank@latimes.com     3.110.64.192         France      $5.55  20.0
# omaryone@va.gov         215.248.16.198  United States      $4.53  20.0

# %%
#les filtres

# %%
df3['gender']
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998      Male
# 999       NaN
# Name: gender, Length: 1000, dtype: object

# %%
#filtrons gender (genre)

# %%
df3['gender'] == "Male"
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
#Filtrons les ranger qui ont des gender (genre) male et female

# %%
df3[df3['gender'] == "Male"]
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
df3[df3['gender'] == "Female"]
# Out:
#       id        date first_name   last_name                       email  \
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
#filtrons le canada et la france

# %%
df3['country'].isin(['France','Canada'])
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: country, Length: 1000, dtype: bool

# %%
country_filt = df3['country'].isin(['France','Canada'])

# %%
df3[country_filt]
# Out:
#        id        date first_name   last_name                      email  \
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# ...

# %%
#convertir le type de donneés en float

# %%
df3_test = df3.copy()
df3_test.price_paid = df3_test.price_paid.apply(lambda x: x.replace('$', ''))
df3_test.price_paid = df3_test.price_paid.astype(float)
df3_test[df3_test['price_paid']>=5.0]
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 5       6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# ..    ...         ...        ...         ...                         ...
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
#Supprimer une colonne

# %%
df3.drop('ip_address', axis = 1)
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender        country price_paid   tax
# 0      Male         Canada      $5.36   NaN
# ...

# %%
df3
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender        country price_paid   tax
# 0      Male         Canada      $5.36   NaN
# ...

# %%
df3.drop('ip_address', axis = 1, inplace = True)

# %%
df3
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender        country price_paid   tax
# 0      Male         Canada      $5.36   NaN
# ...

# %%
df3.set_index('gender',inplace = True)

# %%
df3
# Out:
#           id        date first_name   last_name                       email  \
# gender
# Male       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# Female     2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# Male       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# Female     4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# Male       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ...      ...         ...        ...         ...                         ...
# Female   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# Female   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# Male     998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# Male     999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# NaN     1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#               country price_paid   tax
# gender
# ...

# %%
df3.drop('Male', axis = 0 , inplace = True)

# %%
df3.head()
# Out:
#         id        date first_name   last_name                       email  \
# gender
# Female   2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# Female   4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# Female   6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# Female   7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# Female  13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
#
#               country price_paid   tax
# gender
# Female         Canada      $8.32   NaN
# Female  United States      $3.70  20.0
# Female  United States      $5.82   NaN
# Female         Canada      $6.29   NaN
# Female         Canada      $5.30  20.0

# %%
#supprimons

# %%
df3.drop(['first_name','last_name','email'], axis = 1 , inplace = True)

# %%
df3
# Out:
#           id        date        country price_paid   tax
# gender
# Female     2  03/19/2021         Canada      $8.32   NaN
# Female     4  03/19/2021  United States      $3.70  20.0
# Female     6  03/25/2021  United States      $5.82   NaN
# Female     7  03/14/2021         Canada      $6.29   NaN
# Female    13  03/05/2021         Canada      $5.30  20.0
# ...      ...         ...            ...        ...   ...
# NaN      990  03/16/2021         France      $8.69  20.0
# Female   995  03/17/2021         France      $5.68  20.0
# Female   996  03/24/2021         France      $3.63   NaN
# Female   997  03/17/2021            NaN      $4.59  20.0
# NaN     1000  03/23/2021         Canada      $8.01  20.0
#
# [562 rows x 5 columns]

# %%
# un autres methodes de suppressions

# %%
del df3['id']

# %%
df3
# Out:
#               date        country price_paid   tax
# gender
# Female  03/19/2021         Canada      $8.32   NaN
# Female  03/19/2021  United States      $3.70  20.0
# Female  03/25/2021  United States      $5.82   NaN
# Female  03/14/2021         Canada      $6.29   NaN
# Female  03/05/2021         Canada      $5.30  20.0
# ...            ...            ...        ...   ...
# NaN     03/16/2021         France      $8.69  20.0
# Female  03/17/2021         France      $5.68  20.0
# Female  03/24/2021         France      $3.63   NaN
# Female  03/17/2021            NaN      $4.59  20.0
# NaN     03/23/2021         Canada      $8.01  20.0
#
# [562 rows x 4 columns]

# %%
# traitons nos donneés manquantes

# %%
df4
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df4.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
df4.notnull()
# Out:
#        id  date  first_name  last_name  email  gender  ip_address  country  \
# 0    True  True        True       True   True    True        True     True
# 1    True  True        True       True   True    True        True     True
# 2    True  True        True       True   True    True        True     True
# 3    True  True        True       True   True    True        True     True
# 4    True  True        True       True   True    True        True     True
# ..    ...   ...         ...        ...    ...     ...         ...      ...
# 995  True  True        True       True   True    True        True     True
# 996  True  True        True       True   True    True        True    False
# 997  True  True        True       True   True    True        True     True
# 998  True  True        True       True   True    True        True     True
# 999  True  True        True       True   True   False        True     True
#
#      price_paid    tax
# 0          True  False
# ...

# %%
df4['tax'].notnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998    False
# 999     True
# Name: tax, Length: 1000, dtype: bool

# %%
df4[df4['tax'].notnull()]
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df4[df4['tax'].isnull()]
# Out:
#       id        date first_name   last_name                   email  gender  \
# 0      1  03/28/2021    Marylin      Alders    malders0@shop-pro.jp    Male
# 1      2  03/19/2021      Hinda    Harridge      hharridge1@gnu.org  Female
# 5      6  03/25/2021      Titos  Braybrooke    tbraybrooke5@umn.edu  Female
# 6      7  03/14/2021        Ava     Kencott      akencott6@phoca.cz  Female
# 9     10  03/23/2021  Guglielma      Gookes   ggookes9@amazon.co.uk    Male
# ..   ...         ...        ...         ...                     ...     ...
# 985  986  03/29/2021     Yvonne  Longworthy   ylongworthyrd@163.com  Female
# 992  993  03/04/2021    Maurene  Guilloneau  mguilloneaurk@about.me    Male
# 993  994  03/22/2021      Ossie      Snelle        osnellerl@nhs.uk    Male
# 995  996  03/24/2021       Duff      Errigo    derrigorn@elpais.com  Female
# 998  999  03/17/2021    Paquito       Tesoe  ptesoerq@rakuten.co.jp    Male
#
#          ip_address        country price_paid  tax
# ...

# %%
#remplir certains informations avecdes valeurs

# %%
df4['tax'].fillna(9)
# Out:
# 0       9.0
# 1       9.0
# 2      20.0
# 3      20.0
# 4      20.0
#        ...
# 995     9.0
# 996    20.0
# 997    20.0
# 998     9.0
# 999    20.0
# Name: tax, Length: 1000, dtype: float64

# %%
#SUPPRIMONS LES VALEURS NULL DU RANGER TAX AVEC CETTE METHODE LA FONCTION DROPNA

# %%
df4.dropna(subset=['tax'])
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df4.dropna(subset=['tax'], inplace=True)

# %%
df4
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
#ajoutons des colonnes dans notre data frame

# %%
df5
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df5['tax'].fillna(0,inplace = True)

# %%
df5
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
#verification

# %%
df5.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid     object
# tax           float64
# dtype: object

# %%
df5.price_paid = df5.price_paid.apply(lambda x: x.replace('$', ''))
df5.price_paid = df5.price_paid.astype(float)

# %%
df5
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...

# %%
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df5.dtypes
# Out:
# id              int64
# date           object
# first_name     object
# last_name      object
# email          object
# gender         object
# ip_address     object
# country        object
# price_paid    float64
# tax           float64
# dtype: object

# %%
df5['price_total'] = df5['price_paid'] * (1-df5['tax']/100 )

# %%
df5
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax  price_total
# ...

# %%
# nouvelle colonne pour cree un map

# %%
countries = {'United States':'UN','Canada':'CA','France':'FR','Morocco':'MA'}
df5['countries_codes'] = df5['country'].map(countries)

# %%
df5.head()
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country  price_paid   tax  price_total  \
# 0    160.119.8.119         Canada        5.36   0.0        5.360
# 1   210.51.172.132         Canada        8.32   0.0        8.320
# 2    213.8.101.145  United States        3.73  20.0        2.984
# 3    5.140.237.101  United States        3.70  20.0        2.960
# 4  106.252.162.233        Morocco        9.24  20.0        7.392
#
#   countries_codes
# 0              CA
# 1              CA
# 2              UN
# 3              UN
# 4              MA
